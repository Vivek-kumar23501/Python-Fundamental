# %%
list =[1,2,3,4]
print(list)
# Out:
# [1, 2, 3, 4]

# %%
list.append(5)
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
list.remove(5)
print(list)
# Out:
# [1, 2, 3, 4]

# %%
list.insert(0,10)
print(list)
# Out:
# [10, 1, 2, 3, 4]

# %%
list1=[10,20,30,40]
sum=0
for i in list1:
 sum=sum+i
print(sum)
# Out:
# 100
