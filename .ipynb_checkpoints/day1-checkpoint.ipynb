# %%
print("hello world ")
# Out:
# hello world

# %%
print(hello world )
# Out:
#   Cell In[2], line 1
#     print(hello world )
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print('hello ' , 1 , 4.5, True )
# Out:
# hello  1 4.5 True

# %%
print('hello')
print('world ')
# Out:
# hello
# world

# %%
print('hello ', end=' ')
print('world')
# Out:
# hello  world

# %% [raw]
# print(8)

# %%
print(8)
# Out:
# 8

# %%
print(1e309)
# Out:
# inf

# %%
print(8.55)
# Out:
# 8.55

# %%
print(1.7e309)
# Out:
# inf

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
print('hello world')
# Out:
# hello world

# %%
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
print({'name':'vivek', 'gender': 'male', 'weight':'80'})
# Out:
# {'name': 'vivek', 'gender': 'male', 'weight': '80'}

# %%
#variables 
name='nitish'
print(name)
# Out:
# nitish

# %%
a=5
b=6
print(a+b)
# Out:
# 11

# %%
a=5
print(a)
a='nitish'
print(a)
# Out:
# 5
# nitish

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
#user input

# %%
input("enter your name")
# Out:
# enter your name vivek
# 'vivek'

# %%
fnum=input("enter first number")
snum=input("enter secend number")
result=fnum+snum
print(result)
# Out:
# enter first number 56
# enter secend number 67
# 5667

# %%
print(5+5.6)
# Out:
# 10.6

# %%
print(type(4.5))
# Out:
# <class 'float'>

# %%
fnum=input("enter first number")
snum=input("enter secend number")
result=int(fnum)+int(snum)
print(result)
# Out:
# enter first number 56
# enter secend number 67
# 123
