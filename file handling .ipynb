# %%
f=open("demo.txt","r")
data=f.read()
print(data)
f.close()
# Out:
# i am learning python from apna college

# %%
f=open("demo.txt","r")
data=f.readline(5)
print(data)
f.close()
# Out:
# i am

# %%
f=open("demo.txt","r")
line1=f.readline()
print(line1)
line2=f.readline()
print(line2)

line3=f.readline()
print(line3)
# Out:
# i am learning python from apna college
#
# i am a student of gec west champaran

# %%
f=open("demo.txt", "a")
f.write("i want to ledddddarn python tommmorow")
f.close()

# %%
f=open("sample.txt","a")
