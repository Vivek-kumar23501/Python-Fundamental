# %%
f=open("file.txt","w")
data=f.write("i am a good boy")
print(data)


f.close()
# Out:
# 15

# %%
f=open("demo.txt","r")
line=f.read()
print(line)
# Out:
# i want to learn python tommmorowi want to ledddddarn python tommmorow

# %%
# Write into demo.txt
f = open("demo.txt", "w")
f.write("this is a new line")
f.close()

# Read from demo.txt
f = open("demo.txt", "r")
demo = f.read()
print(demo)
f.close()

# Append & read from sample.txt
g = open("sample.txt", "a+")
g.write("\nthis is my second new line")
g.seek(0)   # cursor ko start pe le jana
good = g.read()
print(good)
g.close()
# Out:
# this is a new line
# this is my secennd new line
# this is my second new line

# %%
import os 
os.remove("file.txt")

# %%
import os 
os.remove("sample.txt")

# %%
with open("sample.txt", "w") as f:
    f.write("This is my first line")

with open("sample.txt", "r") as f:
    print(f.read())
# Out:
# This is my first line
