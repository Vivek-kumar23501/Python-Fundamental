# %%
s="python"
print(len(s))
# Out:
# 6

# %%
s="python"
print(s.upper())
# Out:
# PYTHON

# %%
s="python"
print(s.lower())
# Out:
# python

# %%
s="python"
print(s.capitalize())
# Out:
# Python

# %%
s="python programing language "
print(s.title())
# Out:
# Python Programing Language

# %%
s=" python "
print(s.strip())
# Out:
# python

# %%
s=" i like java "
print(s.replace("java","python"))
# Out:
#  i like python

# %%
s="banana"
print(s.count("a"))
# Out:
# 3

# %%
s="python programing "
print(s.startswith("python"))
# Out:
# True

# %%
s="python programing "
print(s.find("programing"))
# Out:
# 7

# %%
s="python is easy"
print(s.split())
# Out:
# ['python', 'is', 'easy']

# %%
words=["python " , "is", "easy"]
print(" ".join(words))
# Out:
# python  is easy

# %%
s="12345"
print(s.isdigit())
# Out:
# True
