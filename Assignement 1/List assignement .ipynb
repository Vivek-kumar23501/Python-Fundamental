# %%
lst = [1, 2, 3]
lst.append(4)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
lst = [1, 2]
lst.extend([3, 4, 5])
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
lst = [10, 20, 30]
lst.insert(1, 15)
print(lst)
# Out:
# [10, 15, 20, 30]

# %%
lst = [10, 20, 30]
lst.remove(20)
print(lst)
# Out:
# [10, 30]

# %%
lst = [10, 20, 30]
lst.pop()
print(lst)
# Out:
# [10, 20]

# %%
lst = [1, 2, 3]
lst.clear()
print(lst)
# Out:
# []

# %%
lst = [10, 20, 30]
print(lst.index(20))
# Out:
# 1

# %%
lst = [1, 2, 2, 3]
print(lst.count(2))
# Out:
# 2

# %%
lst = [30, 10, 20]
lst.sort()
print(lst)
# Out:
# [10, 20, 30]

# %%
lst = [1, 2, 3]
lst.reverse()
print(lst)
# Out:
# [3, 2, 1]

# %%
lst1 = [1, 2, 3]
lst2 = lst1.copy()
print(lst2)
# Out:
# [1, 2, 3]
