# %%
import numpy as np
arr_2d=np.array([[1,3,4]
                 [4,5,6]
                ])
print(arr_2d.shape)
# Out:
# <>:2: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:2: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\vivek kumar\AppData\Local\Temp\ipykernel_15920\3125019991.py:2: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   arr_2d=np.array([[1,3,4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 import numpy as np
# ----> 2 arr_2d=np.array([[1,3,4]
#       3                  [4,5,6]
#       4                 ])
#       5 print(arr_2d.shape)
#
# TypeError: list indices must be integers or slices, not tuple
