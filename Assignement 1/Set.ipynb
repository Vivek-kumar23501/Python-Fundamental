# %%
s={1,2,3}
s.add(4)
print(s)
# Out:
# {1, 2, 3, 4}

# %%
s={1,2,3}
s.update({3,4,5})
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s={1,2,3}
s.remove(2)
print(s)
# Out:
# {1, 3}

# %%
s={1,2,3}
s.discard(5)
print(s)
# Out:
# {1, 2, 3}

# %%
s={10,20,30}
s.pop()
print(s)
# Out:
# {20, 30}

# %%
s={1,2,3}
s.clear()
print(s)
# Out:
# set()

# %%
s={1,2,3}
s2=s.copy()
print(s2)
# Out:
# {1, 2, 3}

# %%
a={1,2,3}
b={3,4,5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1,2,3}
b={2,3,4}
print(a.intersection(b))
# Out:
# {2, 3}

# %%
a={1,2,3}
b={2,3,4}
print(a.diffrence(b))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 3
#       1 a={1,2,3}
#       2 b={2,3,4}
# ----> 3 print(a.diffrence(b))
#
# AttributeError: 'set' object has no attribute 'diffrence'

# %%
a={1,2,3}
b={2,3,4}
print(a.issubset(b))
# Out:
# False
