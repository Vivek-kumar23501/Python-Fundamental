# %%
file=open("sample.txt", "w")
file.close()

# %%
file=open("sample.txt", "w")
file.write("hello python file")
file.close()

# %%
file=open("sample.txt", "w")
file.writelines({"line1\n", "line2\n" , "line3\n"})
file.close()

# %%
file=open("sample.txt", "r")
data=file.read()
print(data)
file.close()
# Out:
# line2
# line3
# line1

# %%
file=open("sample.txt", "r")

print(file.readline())
file.close()
# Out:
# line2

# %%
file=open("sample.txt", "a")
file.write("\n this is appended text ")
file.close()

# %%
file=open("sample.txt", "r")
file.close()

# %%
file=open("sample.txt","r")
print(file.tell())
file.close()
# Out:
# 0

# %%
file=open("sample.txt", "r")
file.seek(5)
print(file.read())
file.close()
# Out:
# line3
# line1
#
#  this is appended text

# %%
import os
os.rename("sample.txt", "vivek.txt")
