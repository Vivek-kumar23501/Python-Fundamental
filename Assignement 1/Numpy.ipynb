# %%
import numpy as np
a=np.array([1,2,3,4,])
print(a)
# Out:
# [1 2 3 4]

# %%
import numpy as np
a=np.zeros((2,3))
print(a)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
import numpy as np
a=np.ones((3,2))
print(a)
# Out:
# [[1. 1.]
#  [1. 1.]
#  [1. 1.]]

# %%
import numpy as np
a=np.full((2,2),7)
print(a)
# Out:
# [[7 7]
#  [7 7]]

# %%
import numpy as np
a=np.arange(1,10,2)
print(a)
# Out:
# [1 3 5 7 9]

# %%
import numpy as np

a = np.linspace(1, 10, 5)
print(a)
# Out:
# [ 1.    3.25  5.5   7.75 10.  ]

# %%
import numpy as np
a =np.arange(1,7)
b=a.reshape(2,3)
print(b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
import numpy as np
a=np.array([[1,2],
            [3,4]])
print(a.flatten())
# Out:
# [1 2 3 4]

# %%
import numpy as np
a=np.array([[1,2],
            [3,4]])

print( a.T)
# Out:
# [[1 3]
#  [2 4]]

# %%
import numpy as np 
a=np.array([[1,2,3],
            [4,5,6]])
print(a.ndim)
# Out:
# 2

# %%
import numpy as np 
a=np.array([[1,2,3],
            [4,5,6]])
print(a.shape)
# Out:
# (2, 3)

# %%
import numpy as np 
a=np.array([[1,2,3],
            [4,5,6]])
print(a.size)
# Out:
# 6

# %%
import numpy as np 
a=np.array([[1,2,3],
            [4,5,6]])
print(a.dtype)
# Out:
# int64

# %%
import numpy as np 
a=np.array([1,2,3])
b=np.array([4,5,6])
print(a+b)
# Out:
# [5 7 9]

# %%
import numpy as np 
a=np.array([1,2,3])
b=np.array([4,5,6])
print(a*b)
# Out:
# [ 4 10 18]

# %%
import numpy as np 
a=np.array([1,2,3])
print(np.sqrt(a))
# Out:
# [1.         1.41421356 1.73205081]

# %%
import numpy as np 
a=np.array([1,2,3])
print(np.sum(a))
# Out:
# 6

# %%
import numpy as np 
a=np.array([1,2,3])
print(np.mean(a))
# Out:
# 2.0

# %%
import numpy as np 
a=np.array([1,2,3])
print(np.max(a))
# Out:
# 3

# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(np.min(a))
# Out:
# 1

# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(np.var(a))
# Out:
# 2.0

# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(np.std(a))
# Out:
# 1.4142135623730951

# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(np.median(a))
# Out:
# 3.0

# %%
import numpy as np
print(np.random.rand(2,2))
# Out:
# [[0.98855343 0.1807867 ]
#  [0.83016456 0.08386748]]

# %%
import numpy as np
print(np.random.randint(1,10,5))
# Out:
# [5 6 3 8 3]

# %%
import numpy as np
a=np.array([1,2,3,4])
print(np.any(a>3))
# Out:
# True

# %%
import numpy as np
a=np.array([1,2,3,4])
print(np.all(a>0))
# Out:
# True

# %%
import numpy as np
a=np.array([4,1,3,2])
print(np.sort(a))
# Out:
# [1 2 3 4]

# %%
import numpy as np
a=np.array([4,1,3,2])
print(np.argmax(a))
# Out:
# 0

# %%
import numpy as np
a=np.array([4,1,3,2])
print(np.argmin(a))
# Out:
# 1
