# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print(a + b)
# Out:
# [5 7 9]

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print(a * b)
# Out:
# [ 4 10 18]

# %%
import numpy as np

a = np.array([1, 2, 3])

print(np.sqrt(a))
# Out:
# [1.         1.41421356 1.73205081]

# %%
import numpy as np

a = np.array([1, 2, 3])

print(np.sum(a))
# Out:
# 6

# %%
import numpy as np

a = np.array([1, 2, 3])

print(np.mean(a))
# Out:
# 2.0

# %%
import numpy as np

a = np.array([1, 2, 3])

print(np.max(a))
# Out:
# 3

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])

print(np.min(a))
# Out:
# 1

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])

print(np.var(a))
# Out:
# 2.0

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])

print(np.std(a))
# Out:
# 1.4142135623730951

# %%
import numpy as np

a = np.array([1, 2, 3, 4, 5])

print(np.median(a))
# Out:
# 3.0

# %%
import numpy as np

a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

print(a + b)
# Out:
# [5 7 9]
